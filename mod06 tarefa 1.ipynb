# %% [markdown]
# # Módulo 6 tarefa 1
#
# #### 1) A base 'sinasc_RO_2019.csv' contém dados do sistema de nascidos vivos do DataSUS, cujo dicionário de dados está no arquivo 'Estrutura_SINASC_para_CD.pdf'. Carregue esses arquivos.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

sinasc = pd.read_csv('sinasc_RO_2019.csv')
sinasc
# Out:
#        ORIGEM   CODESTAB  CODMUNNASC  LOCNASC  IDADEMAE  ESTCIVMAE  \
# 0           1  2679477.0      110001        1        19        5.0
# 1           1  2679477.0      110001        1        29        2.0
# 2           1  2679477.0      110001        1        37        9.0
# 3           1  2516500.0      110001        1        30        5.0
# 4           1  2516500.0      110001        1        30        2.0
# ...       ...        ...         ...      ...       ...        ...
# 27023       1  2604388.0      510340        1        32        2.0
# 27024       1  2752654.0      510675        1        19        1.0
# 27025       1  9659366.0      510787        1        24        2.0
# 27026       1  9659366.0      510787        1        21        2.0
# 27027       1  2795655.0      510792        1        18        5.0
#
#                 ESCMAE  CODOCUPMAE  QTDFILVIVO  QTDFILMORT  ...  KOTELCHUCK  \
# 0          8 a 11 anos         NaN         0.0         0.0  ...           5
# ...

# %% [markdown]
# ####  2) Monte um gráficos de barras com as variáveis APGAR1, APGAR5, SEXO, GESTACAO, ESTCIVMAE.

# %%
sinasc['APGAR1'].value_counts().sort_index().plot.bar()
plt.title(label='APGAR1')
plt.xlabel(xlabel='Apgar no primeiro minuto')
# Out:
# Text(0.5, 0, 'Apgar no primeiro minuto')

# %%
sinasc['APGAR5'].value_counts().sort_index().plot.bar()
plt.title(label='APGAR5')
plt.xlabel(xlabel='Apgar no quinto minuto')
# Out:
# Text(0.5, 0, 'Apgar no quinto minuto')

# %%
sinasc['SEXO'].value_counts().sort_index().plot.bar()
plt.title(label='SEXO')
plt.xlabel(xlabel='Sexo do nascido')
# Out:
# Text(0.5, 0, 'Sexo do nascido')

# %%
sinasc['GESTACAO'].value_counts().sort_index().plot.bar()
plt.title(label='GESTACAO')
plt.xlabel(xlabel='Tempo de gestação')
# Out:
# Text(0.5, 0, 'Tempo de gestação')

# %%
sinasc['ESTCIVMAE'].value_counts().sort_index().plot.bar()
plt.title(label='ESTCIVMAE')
plt.xlabel(xlabel='Estado civil da mãe')
print('Estado civil, conforme a tabela:\n', 
        '1: Solteira\n', 
        '2: Casada\n', 
        '3: Viúva\n', 
        '4: Separado judicialmente/Divorciado\n', 
        '9: Ignorado')
# Out:
# Estado civil, conforme a tabela:
#  1: Solteira
#  2: Casada
#  3: Viúva
#  4: Separado judicialmente/Divorciado
#  9: Ignorado

# %% [markdown]
# #### 3) Monte um gráfico de barras mostrando o APGAR5 médio por CONSULTAS

# %%
sns.barplot(x='APGAR5', y='CONSULTAS', estimator='mean', data=sinasc)

print('Apgar no quinto minuto: \n0 a 10 \n')
print('Número de consultas de pré-natal: \n1: Nenhuma \n2: de 1 a 3\n3: de 4 a 6\n4: 7 e mais \n9: Ignorado')
# Out:
# Apgar no quinto minuto:
# 0 a 10
#
# Número de consultas de pré-natal:
# 1: Nenhuma
# 2: de 1 a 3
# 3: de 4 a 6
# 4: 7 e mais
# 9: Ignorado

# %% [markdown]
# ####  4) Monte um painel com 4 gráficos mostrando as frequencias de SEXO, GESTACAO, ESTCIVMAE e CONSULTAS

# %%
plt.rc('figure', figsize=(15, 15))
fig, axes = plt.subplots(2, 2)

ax1 = sns.countplot(ax = axes[0, 0], x='SEXO', data= sinasc)

ax2 = sns.countplot(ax = axes[0, 1], x='GESTACAO', data=sinasc)
ax2.set_xticklabels(labels=ax2.get_xticklabels(), rotation=45)

ax3 = sns.countplot(ax = axes[1, 0], x='ESTCIVMAE', data=sinasc)
ax3.set_xlabel(xlabel='Semanas de Gestação')

ax3.set_xticklabels(labels=['1: Solteira',
                            '2: Casada',
                            '3: Viuva', 
                            '4: Separado Jucidialmente\nDivorciado',
                            '5: União consensual',
                            '9: Ignorado'], rotation=45)
ax3.set_xlabel(xlabel='Estado civil')

ax4 = sns.countplot(ax = axes[1, 1], x='CONSULTAS', data=sinasc)
ax4.set_xticklabels(labels=['1: Nenhuma',
                            '2: de 1 a 3',
                            '3: de 4 a 6',
                            '4: 7 e mais',
                            '9: Ignorado'])
ax4.set_xlabel(xlabel='Número de consultas')

plt.subplots_adjust(wspace=0.3, hspace=0.5)
